# %% [markdown]
# To Find the Heights of US Presidents

# %%
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('D:\\Projects\\President_heights\\president_heights.csv')
heights = np.array(data['height(cm)'])
print(heights)
# Out:
# [189 170 189 163 183 171 185 168 173 183 173 173 175 178 183 193 178 173
#  174 183 183 168 170 178 182 180 183 178 182 188 175 179 183 193 182 183
#  177 185 188 188 182 185]

# %%
print('Mean Height:', heights.mean().round(2))
print('Standard Deviation: ', heights.std().round(2))
print('Maximum height: ', heights.max())
print('Minimum height: ', heights.min())
# Out:
# Mean Height: 179.74
# Standard Deviation:  6.93
# Maximum height:  193
# Minimum height:  163

# %%
print("25th percentile: ", np.percentile(heights,25))
print("Median: ", np.median(heights))
print("75th percentile: ", np.percentile(heights,75))
# Out:
# 25th percentile:  174.25
# Median:  182.0
# 75th percentile:  183.0

# %%
sns.set_style("darkgrid", {"grid.color": ".5", "grid.linestyle": "-."})
plt.figure(figsize=(8,5))

# %%
plt.hist(heights, bins = 10, color = 'turquoise', edgecolor = 'black', linewidth = 1.25)
plt.title('Height Distribution of US Presidents', fontsize = 14)
plt.xlabel('heights(cm)', fontsize = 12)
plt.ylabel('number', fontsize = 12)

plt.xticks(fontsize = 10)
plt.yticks(fontsize = 10)

plt.tight_layout()
plt.show()
